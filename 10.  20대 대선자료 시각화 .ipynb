# %%
election <- read.csv("../Data/election_2022.csv",stringsAsFactors = F)
head(election)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정
# 1 서울특별시 종로구   129968   100629  46130  49172 3115
# 2 서울특별시 중구     111448    84998  38244  42906 2310
# 3 서울특별시 용산구   199077   152068  60063  85047 4374
# 4 서울특별시 성동구   252087   197240  84411 103880 5365
# 5 서울특별시 광진구   303582   235471 109922 113733 7072
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416

# %%
tail(election)
# Out:
#     광역시도       시군구   선거인수 투표수 이재명 윤석열 심상정
# 243 경상남도       함양군    34459    26955   8526  16957   528
# 244 경상남도       산청군    31645    24913   7125  16607   464
# 245 경상남도       거창군    53049    41399  11963  27254   895
# 246 경상남도       합천군    39768    31270   6911  22742   511
# 247 제주특별자치도 제주시   408552   296826 157695 122084 10007
# 248 제주특별자치도 서귀포시 155802   112823  55435  50930  3591

# %%
str(election)
summary(election)
# Out:
# 'data.frame':	248 obs. of  7 variables:
#  $ 광역시도: chr  "서울특별시" "서울특별시" "서울특별시" "서울특별시" ...
#  $ 시군구  : chr  "종로구" "중구" "용산구" "성동구" ...
#  $ 선거인수: int  129968 111448 199077 252087 303582 300928 347108 375880 268974 281812 ...
#  $ 투표수  : int  100629 84998 152068 197240 235471 232106 260862 292187 199448 216036 ...
#  $ 이재명  : int  46130 38244 60063 84411 109922 108171 130381 142702 103333 106546 ...
#  $ 윤석열  : int  49172 42906 85047 103880 113733 112890 118201 135044 86540 99780 ...
#  $ 심상정  : int  3115 2310 4374 5365 7072 6416 6899 8952 5245 5605 ...
#    광역시도            시군구             선거인수          투표수
#  Length:248         Length:248         Min.   :  8141   Min.   :  6653
#  Class :character   Class :character   1st Qu.: 47672   1st Qu.: 39216
#  Mode  :character   Mode  :character   Median :154354   Median :114654
#                                        Mean   :176570   Mean   :136148
#                                        3rd Qu.:265099   3rd Qu.:204189
# ...

# %%
sum(is.na(election))
# Out:
# [1] 0

# %%
for( i in 1:7)
    print(table(election[i]))
# Out:
#         강원도         경기도       경상남도       경상북도     광주광역시
#             18             41             22             24              5
#     대구광역시     대전광역시     부산광역시     서울특별시 세종특별자치시
#              8              5             16             25              1
#     울산광역시     인천광역시       전라남도       전라북도 제주특별자치도
#              5             10             22             15              2
#       충청남도       충청북도
#             16             13
#
#           가평군           강남구           강동구           강릉시
#                1                1                1                1
#           강북구           강서구           강진군           강화군
#                1                2                1                1
#           거제시           거창군           경산시           경주시
#                1                1                1                1
#           계룡시           계양구           고령군           고성군
#                1                1                1                2
# ...

# %%
library(plotrix)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
head(election)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정
# 1 서울특별시 종로구   129968   100629  46130  49172 3115
# 2 서울특별시 중구     111448    84998  38244  42906 2310
# 3 서울특별시 용산구   199077   152068  60063  85047 4374
# 4 서울특별시 성동구   252087   197240  84411 103880 5365
# 5 서울특별시 광진구   303582   235471 109922 113733 7072
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416

# %%
pievec <- aggregate(cbind(선거인수 , 투표수) ~ 광역시도, election,sum )
pievec
# Out:
#    광역시도       선거인수 투표수
# 1  강원도          1333621 1015458
# 2  경기도         11106036 8518854
# 3  경상남도        2809907 2146882
# 4  경상북도        2273028 1774284
# 5  광주광역시      1209206  985492
# 6  대구광역시      2046714 1611512
# 7  대전광역시      1233177  945308
# 8  부산광역시      2921510 2200224
# 9  서울특별시      8346647 6501831
# 10 세종특별자치시   288895  231832
# 11 울산광역시       942210  735461
# 12 인천광역시      2519225 1883504
# 13 전라남도        1581278 1282168
# 14 전라북도        1533125 1235212
# 15 제주특별자치도   564354  409649
# 16 충청남도        1796474 1324660
# 17 충청북도        1284087  962333

# %%
vote <- arrange(pievec,desc(투표수))[,3]
vote
# Out:
#  [1] 8518854 6501831 2200224 2146882 1883504 1774284 1611512 1324660 1282168
# [10] 1235212 1015458  985492  962333  945308  735461  409649  231832

# %%
region <- as.character(arrange(pievec,desc(투표수))[,1])
region
# Out:
#  [1] "경기도"         "서울특별시"     "부산광역시"     "경상남도"
#  [5] "인천광역시"     "경상북도"       "대구광역시"     "충청남도"
#  [9] "전라남도"       "전라북도"       "강원도"         "광주광역시"
# [13] "충청북도"       "대전광역시"     "울산광역시"     "제주특별자치도"
# [17] "세종특별자치시"

# %%
ratio <- round(vote/sum(vote) *100,2)

# %%
par(family = "AppleGothic")
options(warn = -1)
pie3D(vote,
      main = "광역시도별 투표율",
      labels = paste(region,"\n",ratio,"%"),
      labelcex = 0.75,
      radius = 0.1,
      explode = 1
     )
# Out:
# Plot with title “광역시도별 투표율”

# %%
# electionSum = 이재명 + 윤석열 + 심상정

election$electionSum <- apply(election[,5:7],1,sum)

# %%
# electionRatio <- 투표수 대비 electionSum의 퍼센트 구해서 넣기
election$electionRatio <- election$electionSum / election$투표수 * 100

# %%
head(election)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 electionSum
# 1 서울특별시 종로구   129968   100629  46130  49172 3115    98417
# 2 서울특별시 중구     111448    84998  38244  42906 2310    83460
# 3 서울특별시 용산구   199077   152068  60063  85047 4374   149484
# 4 서울특별시 성동구   252087   197240  84411 103880 5365   193656
# 5 서울특별시 광진구   303582   235471 109922 113733 7072   230727
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416   227477
#   electionRatio
# 1 97.80183
# 2 98.19055
# 3 98.30076
# 4 98.18292
# 5 97.98531
# 6 98.00565

# %%
# 3명의 후보를 가장 많이 선택한 지역과 가장 적게 선택한 지역 구하기
# election[grep(max(election$electionSum),election$electionSum)[1],1:2]
# election[grep(min(election$electionSum),election$electionSum)[1],1:2]
#1) 정렬

arrange(election,desc(electionRatio))[1,1:2]
arrange(election,desc(electionRatio))[nrow(election),1:2]
# Out:
#   광역시도 시군구
# 1 경기도   성남시분당구
#     광역시도   시군구
# 248 인천광역시 옹진군

# %%
# 2) subset

subset (election, electionRatio == max(election$electionRatio))
subset (election, electionRatio == min(election$electionRatio))
# Out:
#    광역시도 시군구       선거인수 투표수 이재명 윤석열 심상정 electionSum
# 82 경기도   성남시분당구 404493   335434 140966 183094 7005   331065
#    electionRatio
# 82 98.69751
#    광역시도   시군구 선거인수 투표수 이재명 윤석열 심상정 electionSum
# 59 인천광역시 옹진군 18659    14912  5218   8797   304    14319
#    electionRatio
# 59 96.02334

# %%
head(election)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 electionSum
# 1 서울특별시 종로구   129968   100629  46130  49172 3115    98417
# 2 서울특별시 중구     111448    84998  38244  42906 2310    83460
# 3 서울특별시 용산구   199077   152068  60063  85047 4374   149484
# 4 서울특별시 성동구   252087   197240  84411 103880 5365   193656
# 5 서울특별시 광진구   303582   235471 109922 113733 7072   230727
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416   227477
#   electionRatio
# 1 97.80183
# 2 98.19055
# 3 98.30076
# 4 98.18292
# 5 97.98531
# 6 98.00565

# %%
# election_2022_job1.csv 로 저장하기 
write.csv(election ,"../Data/election_2022_job1.csv",row.names = F)

# %%
# 각 후보(윤석열, 이재명, 심상정)의 광역시도별 득표율을 3D Pie Chart로 표현하기
#(단, 득표율이 3% 미만인 광역시도는 광역시도 명만 출력하고 퍼센트는 출력하지 않는다. / 퍼센트 단위는 소수 한자리)

head(election)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 electionSum
# 1 서울특별시 종로구   129968   100629  46130  49172 3115    98417
# 2 서울특별시 중구     111448    84998  38244  42906 2310    83460
# 3 서울특별시 용산구   199077   152068  60063  85047 4374   149484
# 4 서울특별시 성동구   252087   197240  84411 103880 5365   193656
# 5 서울특별시 광진구   303582   235471 109922 113733 7072   230727
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416   227477
#   electionRatio
# 1 97.80183
# 2 98.19055
# 3 98.30076
# 4 98.18292
# 5 97.98531
# 6 98.00565

# %%
simvote <- aggregate(cbind(투표수,심상정) ~ 광역시도,election,sum)
simvote
# Out:
#    광역시도       투표수  심상정
# 1  강원도         1015458  25031
# 2  경기도         8518854 201113
# 3  경상남도       2146882  52591
# 4  경상북도       1774284  33123
# 5  광주광역시      985492  14865
# 6  대구광역시     1611512  31131
# 7  대전광역시      945308  25445
# 8  부산광역시     2200224  47541
# 9  서울특별시     6501831 180324
# 10 세종특별자치시  231832   6780
# 11 울산광역시      735461  21292
# 12 인천광역시     1883504  51852
# 13 전라남도       1282168  16279
# 14 전라북도       1235212  19451
# 15 제주특별자치도  409649  13598
# 16 충청남도       1324660  31789
# 17 충청북도        962333  25247

# %%
simvote$득표율 <- simvote$심상정/sum(simvote$심상정) * 100
simvote
# Out:
#    광역시도       투표수  심상정 득표율
# 1  강원도         1015458  25031  3.1388723
# 2  경기도         8518854 201113 25.2194489
# 3  경상남도       2146882  52591  6.5948797
# 4  경상북도       1774284  33123  4.1536042
# 5  광주광역시      985492  14865  1.8640620
# 6  대구광역시     1611512  31131  3.9038086
# 7  대전광역시      945308  25445  3.1907877
# 8  부산광역시     2200224  47541  5.9616127
# 9  서울특별시     6501831 180324 22.6125209
# 10 세종특별자치시  231832   6780  0.8502079
# 11 울산광역시      735461  21292  2.6700040
# 12 인천광역시     1883504  51852  6.5022095
# 13 전라남도       1282168  16279  2.0413768
# 14 전라북도       1235212  19451  2.4391437
# 15 제주특별자치도  409649  13598  1.7051810
# 16 충청남도       1324660  31789  3.9863214
# 17 충청북도        962333  25247  3.1659586

# %%
simvote <- arrange(simvote,desc(득표율))
simvote
# Out:
#    광역시도       투표수  심상정 득표율
# 1  경기도         8518854 201113 25.2194489
# 2  서울특별시     6501831 180324 22.6125209
# 3  경상남도       2146882  52591  6.5948797
# 4  인천광역시     1883504  51852  6.5022095
# 5  부산광역시     2200224  47541  5.9616127
# 6  경상북도       1774284  33123  4.1536042
# 7  충청남도       1324660  31789  3.9863214
# 8  대구광역시     1611512  31131  3.9038086
# 9  대전광역시      945308  25445  3.1907877
# 10 충청북도        962333  25247  3.1659586
# 11 강원도         1015458  25031  3.1388723
# 12 울산광역시      735461  21292  2.6700040
# 13 전라북도       1235212  19451  2.4391437
# 14 전라남도       1282168  16279  2.0413768
# 15 광주광역시      985492  14865  1.8640620
# 16 제주특별자치도  409649  13598  1.7051810
# 17 세종특별자치시  231832   6780  0.8502079

# %%
ratio <- round(simvote[,4],1)
ratio
# Out:
#  [1] 25.2 22.6  6.6  6.5  6.0  4.2  4.0  3.9  3.2  3.2  3.1  2.7  2.4  2.0  1.9
# [16]  1.7  0.9

# %%
strratio <- ifelse(ratio >= 3, paste(ratio,"%" ) ,"" )

# %%
par(family = "AppleGothic")
pie3D(simvote[,2],
     main = "심상정 광역시별 득표율",
      labels = paste(simvote[,1], "\n",strratio),
      labelcex = 0.7
     )
# Out:
# Plot with title “심상정 광역시별 득표율”

# %%
head(election)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 electionSum
# 1 서울특별시 종로구   129968   100629  46130  49172 3115    98417
# 2 서울특별시 중구     111448    84998  38244  42906 2310    83460
# 3 서울특별시 용산구   199077   152068  60063  85047 4374   149484
# 4 서울특별시 성동구   252087   197240  84411 103880 5365   193656
# 5 서울특별시 광진구   303582   235471 109922 113733 7072   230727
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416   227477
#   electionRatio
# 1 97.80183
# 2 98.19055
# 3 98.30076
# 4 98.18292
# 5 97.98531
# 6 98.00565

# %%
# 수도권(경기도, 서울, 인천)의 투표인구수 퍼센트

sum(subset(election,광역시도 == '서울특별시'|광역시도 == '경기도'|광역시도 == '인천광역시')[,4]) /sum(election$투표수) * 100
# Out:
# [1] 50.06473

# %%
sum(grep(ele))
# Out:
# Error in grep(ele): 기본값이 없는 인수 "x"가 누락되어 있습니다
# Traceback:
#
# 1. grep(ele)

# %%
sum(pievec[grep("인천광역시|서울특별시|경기도",pievec$광역시도),3])/sum(election$투표수) * 100

# %%
election

# %%
youn  <-subset(election, 광역시도 == "서울특별시")
youn

# %%
youn <-arrange(youn,desc(youn$윤석열))
head(youn)

# %%
younpie <- youn[,c(2,6)]
younpie

# %%
sum(younpie[6:nrow(younpie),2])

# %%
tmp1 <- younpie[-6:-nrow(younpie),]
tmp1

# %%
data.frame(시군구 = '기타', 윤석열  = sum(younpie[6:nrow(younpie),2]) )

# %%
rbind(tmp1,data.frame(시군구 = '기타', 윤석열  = sum(younpie[6:nrow(younpie),2]) ))

# %%
str(younpie)

# %%
younpie <- rbind(tmp1,data.frame(시군구 = '기타', 윤석열  = sum(younpie[6:nrow(younpie),2]) ))
younpie

# %%
str(younpie)

# %%
younpie[,1]
label =paste(younpie[,1], "\n", round(younpie[,2]/sum(younpie[,2]) * 100,2) , "%")

# %%
par(family = "AppleGothic")
pie3D(younpie[,2],
      main = "윤석열 후보 서울 득표 Top5",
      labels = label,
      explode = 0.1,
      labelcex = 0.7
     )

# %% [markdown]
# # 대선주자 출생지별 득표율 분석
# - 윤석열 후보의 출생지는 서울특별시 성북구

# %%
election_seongbuk <- election[election$광역시도 == '서울특별시' & election$시군구 == '성북구',]
election_seongbuk

# %%
str(election_seongbuk)

# %%
election_seongbuk[,"이재명"]

# %%
tt <- c(election[1:2,5:7],기타= election_seongbuk[1:2,4] - sum(election_seongbuk[1,5:7]))
as.data.frame(tt)

tt <- data.frame(cbind(a = c(a = 1:2, b= 1:2),b = 1:4 ))
cbind(election,iris[1:2,])

# %%
c <- 0
for(i in 5:7)
    c <- c(c,round (election_seongbuk[,i]/election_seongbuk[,4] *100 ,2))
election_seongbuk_ratio <- c(c[-1], round(100 -election_seongbuk[,"electionRatio"],2))

apply(election[3,5:7],1,table)

# %%
election_seongbuk_candidate <- c(colnames(election_seongbuk[,5:7]),"기타")
election_seongbuk_candidate

# %%
par(family =  "AppleGothic")
pie3D(election_seongbuk_ratio,
      main = "서울시 성북구의 후보별 득표율",
      labels = paste(election_seongbuk_candidate, "\n", election_seongbuk_ratio , "%"),
      labelcex = 0.7,
      col = c("skyblue","red","yellow","gray")
     )

# %%
# 서울 특별시 Data만 출력하기
subset(election,광역시도 == '서울특별시')
election_seoul<-election[election$광역시도=='서울특별시',]
election_seoul_윤석열 <-arrange(election_seoul,desc(윤석열))[,c(2,6)]

head(election_seoul_윤석열)

# %%
# Ratio 구하기
election_seoul_윤석열_ratio<-round(c(election_seoul_윤석열[1:5,2],sum(election_seoul_윤석열[-c(1:5),2]))/
sum(election_seoul_윤석열$윤석열)*100,2)

election_seoul_윤석열_ratio

# %%
#label만들기
election_seoul_윤석열_label<-
c(as.character(election_seoul_윤석열$시군구[1:5]),"기타")

election_seoul_윤석열_label

# %% [markdown]
# ---
# # 투표수가 가장 많은 4 지역(광역시도)의 후보별 득표수 차이를 막대그래프로 시각화

# %%
head(election)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 electionSum
# 1 서울특별시 종로구   129968   100629  46130  49172 3115    98417
# 2 서울특별시 중구     111448    84998  38244  42906 2310    83460
# 3 서울특별시 용산구   199077   152068  60063  85047 4374   149484
# 4 서울특별시 성동구   252087   197240  84411 103880 5365   193656
# 5 서울특별시 광진구   303582   235471 109922 113733 7072   230727
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416   227477
#   electionRatio
# 1 97.80183
# 2 98.19055
# 3 98.30076
# 4 98.18292
# 5 97.98531
# 6 98.00565

# %%
vote <- arrange(aggregate(cbind(투표수,이재명,윤석열,심상정) ~광역시도 ,election, sum ),desc(투표수))[1:4,]
vote
# Out:
#   광역시도   투표수  이재명  윤석열  심상정
# 1 경기도     8518854 4297931 3859666 201113
# 2 서울특별시 6501831 2944981 3255747 180324
# 3 부산광역시 2200224  831896 1270072  47541
# 4 경상남도   2146882  794130 1237346  52591

# %%
votemat <- t(as.matrix(vote[,3:5]))
votemat
# Out:
#        1       2       3       4
# 이재명 4297931 2944981  831896  794130
# 윤석열 3859666 3255747 1270072 1237346
# 심상정  201113  180324   47541   52591

# %%
#colnames(votemat) <- c("경기도","서울특별시","부산광역시","경상남도")
colnames(votemat) <- vote[1:4,1]

# %%
par(family = "AppleGothic")
options(warn = -1)
options(scipen = 100)


barplot(votemat,
        main = "투표수가 가장 많은 4지역의 후보별 득표수 차이",
        beside = T,
        ylim = c(0,5000000),
        col = c("skyblue","red","yellow"),
        legend.text = T,

       )

# legend(7,80,  
#        rownames(VADeaths),
#        fill = rainbow(5), 
#        cex = 0.7 
#       )
# Out:
# Plot with title “투표수가 가장 많은 4지역의 후보별 득표수 차이”

# %% [markdown]
# ---
# # 투표수가 높은 시군구의 후보별 득표수를 막대그래프로 시각화

# %%
head(election)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 electionSum
# 1 서울특별시 종로구   129968   100629  46130  49172 3115    98417
# 2 서울특별시 중구     111448    84998  38244  42906 2310    83460
# 3 서울특별시 용산구   199077   152068  60063  85047 4374   149484
# 4 서울특별시 성동구   252087   197240  84411 103880 5365   193656
# 5 서울특별시 광진구   303582   235471 109922 113733 7072   230727
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416   227477
#   electionRatio
# 1 97.80183
# 2 98.19055
# 3 98.30076
# 4 98.18292
# 5 97.98531
# 6 98.00565

# %%
vote_시군구 <- arrange(election,desc(투표수))[1:5,c(1:2,5:7)]
vote_시군구
# Out:
#   광역시도   시군구   이재명 윤석열 심상정
# 1 경기도     화성시   283324 236055 12955
# 2 경기도     부천시   285227 224331 13249
# 3 경기도     남양주시 239179 203075 10089
# 4 서울특별시 송파구   180490 255166 10652
# 5 서울특별시 강서구   190000 181510 11100

# %%
vote_시군구_mat<-t(as.matrix(vote_시군구[,3:5]))
colnames(vote_시군구_mat) <- paste(vote_시군구[1:5,1],vote_시군구[1:5,2])
# Out:
#        경기도 화성시 경기도 부천시 경기도 남양주시 서울특별시 송파구
# 이재명 283324        285227        239179          180490
# 윤석열 236055        224331        203075          255166
# 심상정  12955         13249         10089           10652
#        서울특별시 강서구
# 이재명 190000
# 윤석열 181510
# 심상정  11100

# %%
temp <- vote_시군구_mat[1,]
vote_시군구_mat[1,] <- vote_시군구_mat[3,]
vote_시군구_mat[3,] <- temp

# %%
class(rownames(vote_시군구_mat))
par(family = "AppleGothic")
barplot(vote_시군구_mat,
        main = "투표수 높은 지역의 후보별 투표수",
        cex.names = 0.7,
        legend = T,
        ylim = c(0,600000),
        col = c("skyblue","red","yellow"),
        arg.legend = list(x = "topleft"),
       )
# Out:
# [1] "character"
# Plot with title “투표수 높은 지역의 후보별 투표수”

# %%
help(barplot)

# %%
barplot(VADeaths, angle = 15+10*1:5, density = 20, col = "black",
        legend = rownames(VADeaths))
# Out:
# plot without title

# %%
result <-data.frame(이재명 = "47.83",윤석열 = "48.56" ,심상정  = "2.37" ,stringsAsFactors = F)

result
# Out:
#   이재명 윤석열 심상정
# 1 47.83  48.56  2.37

# %%
for (i in 1:3)
    result[,i] <- as.numeric(result[,i])

# %%
str(result)
# Out:
# 'data.frame':	1 obs. of  3 variables:
#  $ 이재명: num 47.8
#  $ 윤석열: num 48.6
#  $ 심상정: num 2.37

# %%
test <-cbind( election[,1:2],election[,5:7]/election[,4] * 100)
head(test)
# Out:
#   광역시도   시군구   이재명   윤석열   심상정
# 1 서울특별시 종로구   45.84166 48.86464 3.095529
# 2 서울특별시 중구     44.99400 50.47883 2.717711
# 3 서울특별시 용산구   39.49746 55.92695 2.876345
# 4 서울특별시 성동구   42.79609 52.66680 2.720037
# 5 서울특별시 광진구   46.68176 48.30022 3.003342
# 6 서울특별시 동대문구 46.60414 48.63726 2.764254

# %%
head (election)
# Out:
#   광역시도   시군구   선거인수 투표수 이재명 윤석열 심상정 electionSum
# 1 서울특별시 종로구   129968   100629  46130  49172 3115    98417
# 2 서울특별시 중구     111448    84998  38244  42906 2310    83460
# 3 서울특별시 용산구   199077   152068  60063  85047 4374   149484
# 4 서울특별시 성동구   252087   197240  84411 103880 5365   193656
# 5 서울특별시 광진구   303582   235471 109922 113733 7072   230727
# 6 서울특별시 동대문구 300928   232106 108171 112890 6416   227477
#   electionRatio
# 1 97.80183
# 2 98.19055
# 3 98.30076
# 4 98.18292
# 5 97.98531
# 6 98.00565

# %%
a <- test[abs(test$이재명-47.83)<= 1 & abs(test$윤석열-48.56)<= 1 & abs(test$심상정 - 2.37) <= 1,]

# %%
str(a)
# Out:
# 'data.frame':	7 obs. of  5 variables:
#  $ 광역시도: chr  "인천광역시" "인천광역시" "대전광역시" "대전광역시" ...
#  $ 시군구  : chr  "동구" "미추홀구" "유성구" "대덕구" ...
#  $ 이재명  : num  46.9 47.1 47.1 46.9 47.8 ...
#  $ 윤석열  : num  48 47.8 48.2 47.8 47.8 ...
#  $ 심상정  : num  2.92 2.74 2.81 2.72 2.67 ...

# %%
x<- 0
for( i in 1:nrow(a)){
     if( a[i,3] > a[i,4]){
         x<-c(x, i)
     }
}
x[-1]
a[-x,]
# Out:
# numeric(0)
#      광역시도 시군구 이재명 윤석열 심상정

# %%
a
# Out:
#     광역시도   시군구       이재명   윤석열   심상정   samsum
# 51  인천광역시 동구         46.91089 48.04976 2.922919 9.792215
# 52  인천광역시 미추홀구     47.08443 47.80874 2.743668 9.792215
# 68  대전광역시 유성구       47.05121 48.19437 2.810061 9.792215
# 69  대전광역시 대덕구       46.89525 47.79644 2.721743 9.792215
# 137 충청북도   청주시흥덕구 47.00549 47.62376 2.914169 9.792215

# %%
y <- 0
for(i in 1:5){
    y <- c(y, sum(c(abs(a[i,3]-47.83),abs(a[i,4]-48.56),abs(a[i,5]-2.37))))
}

y = y[-1]
a$samsum <- y

# %%
answer <- arrange(a,samsum)
answer
# Out:
#   광역시도   시군구       이재명   윤석열   심상정   samsum
# 1 대전광역시 유성구       47.05121 48.19437 2.810061 1.584484
# 2 인천광역시 미추홀구     47.08443 47.80874 2.743668 1.870498
# 3 인천광역시 동구         46.91089 48.04976 2.922919 1.982266
# 4 대전광역시 대덕구       46.89525 47.79644 2.721743 2.050051
# 5 충청북도   청주시흥덕구 47.00549 47.62376 2.914169 2.304917

# %%
answer[,3] <- abs(answer[,3]-47.83)
answer[,4] <- abs(answer[,4]-48.56)
answer[,5] <- abs(answer[,5]-2.37)
a$samsum <- apply()

# %%
answer
# Out:
#   광역시도   시군구       이재명    윤석열    심상정    samsum
# 1 대전광역시 유성구       0.7787895 0.3656331 0.4400612 1.584484
# 2 인천광역시 미추홀구     0.7455664 0.7512634 0.3736678 1.870498
# 3 인천광역시 동구         0.9191050 0.5102419 0.5529190 1.982266
# 4 대전광역시 대덕구       0.9347451 0.7635631 0.3517427 2.050051
# 5 충청북도   청주시흥덕구 0.8245077 0.9362394 0.5441695 2.304917

# %%
answer_mat <- as.matrix(answer[3:6])

# %%
answer_mat = t(answer_mat)
answer_mat
# Out:
#        대전광역시 인천광역시 인천광역시 대전광역시 충청북도
# 이재명 0.7787895  0.7455664  0.9191050  0.9347451  0.8245077
# 윤석열 0.3656331  0.7512634  0.5102419  0.7635631  0.9362394
# 심상정 0.4400612  0.3736678  0.5529190  0.3517427  0.5441695
# samsum 1.5844838  1.8704975  1.9822660  2.0500510  2.3049166

# %%
colnames(answer_mat) = paste(answer[1:5,1],answer[1:5,2])

# %%
par(family = "AppleGothic")

barplot(answer_mat[4,],
        main = "지역구별 대선결과 반영 오차비율 합이 낮은 순위 Top5",
        beside = T,
        ylim = c(0,3),
        cex.names = 0.5,
        col = c("darkblue"),

       )

# legend (3,1,
#         rownames(answer_mat)[1:3],
#         fill = c("darkblue","red","yellow")

#         )
# Out:
# Plot with title “지역구별 대선결과 반영 오차비율 합이 낮은 순위 Top5”

# %%
par(family = "AppleGothic")
options(scipen = 100)
barplot(answer_mat[4,],
        main = "지역구별 대선결과 반영 오차비율 합이 낮은 순위 Top5",
        beside = T,
        ylim = c(0,3),
        cex.names = 0.5,
        col = c("darkblue"),

       )
# Out:
# Plot with title “지역구별 대선결과 반영 오차비율 합이 낮은 순위 Top5”
