# %%
df <-read.csv("../Data/dd21.03.csv")

# %%
head(df)
# Out:
#   대여일자   대여시간 대여소번호 대여소명
# 1 2021-01-01 0        1347       1347. 길음래미안아파트817동 상가 앞
# 2 2021-01-01 0        1349       1349. 월계2교 버스정류장 앞
# 3 2021-01-01 0        1168       1168. 마곡엠밸리10단지 앞
# 4 2021-01-01 0        2619       2619. 석촌고분역 4번출구
# 5 2021-01-01 0         536       536. 행당역 2번출구 앞
# 6 2021-01-01 0         192       192. 연서어린이공원
#   대여구분코드 성별 연령대코드 이용건수 운동량 탄소량 이동거리 사용시간
# 1 정기권            ~10대      2        28.90  0.23    992.78  13
# 2 정기권            ~10대      1        34.38  0.26   1127.50  10
# 3 정기권            ~10대      1        0.00   0.00      0.00   7
# 4 정기권            ~10대      1        38.75  0.38   1658.34  14
# 5 정기권            ~10대      1        12.96  0.17    743.88   5
# 6 정기권            ~10대      1        23.40  0.21    908.98   7

# %%
unique(df$대여일자)
# Out:
#  [1] 2021-01-01 2021-01-02 2021-01-03 2021-01-04 2021-01-05 2021-01-06
#  [7] 2021-01-07 2021-01-08 2021-01-09 2021-01-10 2021-01-11 2021-01-12
# [13] 2021-01-13 2021-01-14 2021-01-15 2021-01-16 2021-01-17 2021-01-18
# [19] 2021-01-19 2021-01-20 2021-01-22 2021-01-23 2021-01-24 2021-01-25
# [25] 2021-01-26 2021-01-27 2021-01-28 2021-01-29 2021-01-30 2021-01-31
# 30 Levels: 2021-01-01 2021-01-02 2021-01-03 2021-01-04 ... 2021-01-31

# %%
df3 <- read.table("../Data/dd21.03.csv",header = T)

# %%
write.csv(df3,"../Data/dd23.03-1.csv", row.names = F)

# %%
df4 <- read.csv("../Data/dd23.03-1.csv")

# %%
head(df3)
# Out:
#   대여일자   대여시간 대여소번호 대여소명                      대여구분코드
# 1 2021-03-01 0        1155       1155. 기쁜우리복지관          정기권
# 2 2021-03-01 0         515       515. 광양중학교 앞            정기권
# 3 2021-03-01 0        2067       2067. LG전자 베스트?대리점 앞 정기권
# 4 2021-03-01 0        1191       1191. 마곡역 교차로(NH농협)   정기권
# 5 2021-03-01 0         367       367. 독립문역 3-1번출구       정기권
# 6 2021-03-01 0        2525       2525.반포쇼핑타운 2동 앞      정기권
#   성별 연령대코드 이용건수 운동량 탄소량 이동거리 사용시간
# 1      ~10대      1        41.28  0.25   1097.30  48
# 2      ~10대      1        37.41  0.34   1453.44   7
# 3      ~10대      1        0.00   0.00      0.00  11
# 4      ~10대      1        57.54  0.45   1937.28  45
# 5      ~10대      1        46.15  0.36   1553.83   9
# 6      ~10대      1        34.41  0.31   1336.79   5

# %%
head(df4)
# Out:
#   대여일자   대여시간 대여소번호 대여소명                      대여구분코드
# 1 2021-03-01 0        1155       1155. 기쁜우리복지관          정기권
# 2 2021-03-01 0         515       515. 광양중학교 앞            정기권
# 3 2021-03-01 0        2067       2067. LG전자 베스트?대리점 앞 정기권
# 4 2021-03-01 0        1191       1191. 마곡역 교차로(NH농협)   정기권
# 5 2021-03-01 0         367       367. 독립문역 3-1번출구       정기권
# 6 2021-03-01 0        2525       2525.반포쇼핑타운 2동 앞      정기권
#   성별 연령대코드 이용건수 운동량 탄소량 이동거리 사용시간
# 1      ~10대      1        41.28  0.25   1097.30  48
# 2      ~10대      1        37.41  0.34   1453.44   7
# 3      ~10대      1        0.00   0.00      0.00  11
# 4      ~10대      1        57.54  0.45   1937.28  45
# 5      ~10대      1        46.15  0.36   1553.83   9
# 6      ~10대      1        34.41  0.31   1336.79   5

# %%
df4$

# %%
unique(df4$대여소명)
# Out:
#    [1] 1155. 기쁜우리복지관
#    [2] 515. 광양중학교 앞
#    [3] 2067. LG전자 베스트?대리점 앞
#    [4] 1191. 마곡역 교차로(NH농협)
#    [5] 367. 독립문역 3-1번출구
#    [6] 2525.반포쇼핑타운 2동 앞
#    [7] 771.목동아파트 703동 앞
#    [8] 2905.중계주공6단지
#    [9] 518. 청계천 박물관 앞
#   [10] 3711. 월계2교 교차로
#   [11] 3765. 문소빌딩
#   [12] 4122. 청계9가교차로 앞
#   [13] 602. 장안동 사거리
#   [14] 900. 은평예술회관
#   [15] 1318. 길음역 3번출구 뒤
#   [16] 1431. 중랑구청 사거리
#   [17] 1936. 개봉역 1번 출구 자전거보관서쪽
#   [18] 736. 오솔길공원
#   [19] 744. 신목동역 2번 출구
#   [20] 946. 독바위역
#   [21] 1044. 굽은다리역
#   [22] 1268. 몽촌토성역 1번출구 옆
#   [23] 1274. 영파여고 앞
#   [24] 1442. (구)신한은행 중랑교지점
#   [25] 1447. 면목역 3번출구
#   [26] 1650. 중계근린공원내
#   [27] 2269. 주홍교 하부
#   [28] 3509. 세종사이버대학교
#   [29] 3515. 서울숲 관리사무소
#   [30] 1958. 강서수도사업소민원센터
#   [31] 1661. 당현천근린공원
#   [32] 1673. 노원역 5번출구
#   [33] 646. 장한평역 1번출구 (국민은행앞)
#   [34] 650. 중랑교사거리
#   [35] 277. 영등포뉴타운지하상가 2번게이트
#   [36] 1451. 중랑세무서
#   [37] 1355. 보문2교
#   [38] 279. 영등포 푸르지오 아파트
#   [39] 1051. 양지시장 (용성약국앞) 입구
#   [40] 1458. 상봉터미널2
# ...

# %%
unique(df3$V1)
# Out:
#  [1] 대여일자   2021-03-01 2021-03-02 2021-03-03 2021-03-04 2021-03-05
#  [7] 2021-03-06 2021-03-07 2021-03-08 2021-03-10 2021-03-11 2021-03-12
# [13] 2021-03-13 2021-03-14 2021-03-15 2021-03-16 2021-03-17 2021-03-18
# [19] 2021-03-19 2021-03-20 2021-03-21 2021-03-22 2021-03-23 2021-03-24
# [25] 2021-03-25 2021-03-26 2021-03-27 2021-03-28 2021-03-29 2021-03-30
# [31] 2021-03-31
# 31 Levels: 2021-03-01 2021-03-02 2021-03-03 2021-03-04 ... 대여일자

# %%
library(stringr)

# %%
?str_replace_all

# %%
str_replace_all()

# %%
format(20220102, format="%Y-%m-%d")
# Out:
# [1] "20220102"

# %%
format(as.Date(as.character(20220102),format="%Y%m%d"),"%Y-%m-%d")
# Out:
# [1] "2022-01-02"

# %%
a <- rep(c("a","b"),2)

# %%
a
# Out:
# [1] "a" "b" "a" "b"
